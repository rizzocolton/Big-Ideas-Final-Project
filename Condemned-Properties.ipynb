# %%
import pandas as pd

properties=pd.read_csv("Condemned-Properties.csv")
properties.head(10)
# Out:
#      _id         parcel_id                                   address  \
# 0  36301  0015L00194000000        113 CHALFONT ST, Pittsburgh, 15210
# 1  36302  0015L00194000000        113 CHALFONT ST, Pittsburgh, 15210
# 2  36303  0232B00068000000     1825 MAPLEWOOD AVE, Pittsburgh, 15221
# 3  36304  0232B00068000000     1825 MAPLEWOOD AVE, Pittsburgh, 15221
# 4  36305  0011A00235000000              No primary address specified
# 5  36306  0185S00058000000  5622 DELLAGLEN AVE, Pittsburgh, PA 15207
# 6  36307  0014N00219000000        418 ROCHELLE ST, Pittsburgh, 15210
# 7  36308  0027B00097000000           3216 CAMP ST, Pittsburgh, 15219
# 8  36309  0015L00050000000        56 LAFFERTY AVE, Pittsburgh, 15210
# 9  36310  0046G00142000000              No primary address specified
#
#    zip_code                                    owner  \
# 0     15210                        JAMES CHARMETTE Y
# 1     15210                        JAMES CHARMETTE Y
# ...
