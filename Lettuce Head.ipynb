# %% [markdown]
# #### In the name of Liz Truss I shal prove the worth of <Insert Munincipality Here>

# %%
import pandas as pd
asbestos = pd.read_csv("Asbestos-Permits.csv")

# %%
mask = asbestos["city"] == "PITTSBURGH"

# %%
print(asbestos[mask].head(10))
# Out:
#         _id permit_number                                      s_name  \
# 0   7251007     PAA224069                            VACANT RESIDENCE
# 10  7251017     PAA224030                  OLYMPIA PARK SHELTER HOUSE
# 22  7251029     PAA210582  UPARC BUILDING BUILDING A-8 LABS 102 & 104
# 23  7251030     PAA210583       UPARC BUILDING B1 ROOMS 321; 325; 327
# 29  7251036     PAA212544                              UPARC 2021 O&M
# 37  7251044     PAA220011                               BROUGHTON VFD
# 46  7251053     UND220010                TOWNE CENTRE OFFICE BUILDING
# 49  7251056     UND210124                UNIVERSITY SQUARE APARTMENTS
# 50  7251057     PAA200332                LEMINGTON SENIOR DEVELOPMENT
# 51  7251058     PAA200239                             FORMER PNC BANK
#
#                 s_address        city z_code   p_fee pa_license_no  \
# 0        5203  COLUMBO ST  PITTSBURGH  15224   350.0           975
# ...
